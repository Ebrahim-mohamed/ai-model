# %% [markdown]
# # Nile-Chat 12B v2 — Merge, Push to Hugging Face, and Serve
#
# Merges the v2 LoRA adapter (trained in `nile_chat_finetune_v2_colab.ipynb`) into the
# base model, pushes the merged model to a **new** Hugging Face repo
# (`mennaharmas/raylab-nilechat-12b-v2` — separate from the v1 repo `mennaharmas/raylab-nilechat-12b`, so the
# currently-deployed v1 model is never overwritten while v2 is being validated), and
# serves it with vLLM for real testing.
#
# **Security note on the v1 notebook this is adapted from**: its serve cell had a real
# Hugging Face token hardcoded in plaintext (`os.environ["HF_TOKEN"] = "hf_..."`).
# It was not committed to git, but it's a live secret sitting in a local file — rotate
# that token on huggingface.co/settings/tokens as a precaution, and this notebook
# never hardcodes one — it reads from Colab's secret store (`userdata`) the same way
# the training notebook already does for the Hub login.

# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ## Stage 12 — Merge LoRA adapter into base model

# %%
# Same install as the training notebook -- a fresh runtime needs it again.
# !pip uninstall -y torch torchvision torchaudio vllm
# !pip install -qU uv
# !uv pip install --system vllm --torch-backend=auto
# !pip uninstall -y torchao
# !pip install -qU "transformers>=4.55.0,<=5.8.0,!=4.57.0,!=5.6.0" "datasets>=2.16.0,<=4.0.0" "accelerate>=1.3.0,<=1.15.0" "peft>=0.18.0,<=0.20.0" "trl>=0.18.0,<=0.24.0"
# !git clone --depth 1 https://github.com/hiyouga/LLaMA-Factory.git
# !cd LLaMA-Factory && pip install -e . --no-deps
# Out:
# Found existing installation: torch 2.13.0+cu132
# Uninstalling torch-2.13.0+cu132:
#   Successfully uninstalled torch-2.13.0+cu132
# Found existing installation: torchvision 0.28.0+cu132
# Uninstalling torchvision-0.28.0+cu132:
#   Successfully uninstalled torchvision-0.28.0+cu132
# WARNING: Skipping torchaudio as it is not installed.
# Found existing installation: vllm 0.28.0
# Uninstalling vllm-0.28.0:
#   Successfully uninstalled vllm-0.28.0
# Using Python 3.13.15 environment at: /usr
# Resolved 196 packages in 437ms
# Prepared 3 packages in 0.40ms
# Installed 4 packages in 212ms
#  + torch==2.13.0+cu132
#  + torchaudio==2.11.0+cpu
#  + torchvision==0.28.0+cu132
#  + vllm==0.28.0
# WARNING: Skipping torchao as it is not installed.
# fatal: destination path 'LLaMA-Factory' already exists and is not an empty directory.
# Obtaining file:///content/LLaMA-Factory
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: llamafactory
#   Building editable for llamafactory (pyproject.toml) ... done
#   Created wheel for llamafactory: filename=llamafactory-0.9.6.dev0-py3-none-any.whl size=27393 sha256=8c839cd85f45f752a1a2fca67446fac49aeba01a44e433a16336fac389212d21
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wcq8s587/wheels/c5/91/f5/9d5d6d4691fb180faab957348742c8da0755f8d9902661f46f
# Successfully built llamafactory
# Installing collected packages: llamafactory
#   Attempting uninstall: llamafactory
#     Found existing installation: llamafactory 0.9.6.dev0
#     Uninstalling llamafactory-0.9.6.dev0:
#       Successfully uninstalled llamafactory-0.9.6.dev0
# Successfully installed llamafactory-0.9.6.dev0

# %%
import torch

torch_version = torch.__version__.split("+")[0]
torch_cuda = torch.version.cuda
cuda_tag = "cu" + torch_cuda.replace(".", "")

print(f"Detected torch=={torch_version} built for CUDA {torch_cuda} -> installing matched "
      f"torchvision from index {cuda_tag}, leaving torchaudio uninstalled")

# !pip install -q "torch=={torch_version}" torchvision --index-url https://download.pytorch.org/whl/{cuda_tag}
# !pip uninstall -y -q torchaudio

import subprocess
check = subprocess.run(
    ["python", "-c", "import torch, torchvision; "
     "print('torch:', torch.__version__, torch.version.cuda); "
     "print('torchvision:', torchvision.__version__)"],
    capture_output=True, text=True,
)
print(check.stdout.strip())
assert check.returncode == 0, f"torch/torchvision import failing:\n{check.stderr}"
print("torch/torchvision aligned and importable. torchaudio intentionally left uninstalled.")
# Out:
# Detected torch==2.13.0 built for CUDA 13.2 -> installing matched torchvision from index cu132, leaving torchaudio uninstalled
# torch: 2.13.0+cu132 13.2
# torchvision: 0.28.0+cu132
# torch/torchvision aligned and importable. torchaudio intentionally left uninstalled.

# %%
import os
from google.colab import userdata

# Token from Colab's secret store -- never hardcoded (see this notebook's intro cell
# re: the v1 notebook's leaked plaintext token). Only needed because the repo above
# is private.
os.environ["HF_TOKEN"] = userdata.get('huggingface')

# !nohup vllm serve "mennaharmas/raylab-nilechat-12b-v2" \
    --dtype bfloat16 \
    --max-model-len 8192 \
    --gpu-memory-utilization 0.85 \
    --port 8001 \
    --served-model-name raylab-nilechat-finetuned \
    > vllm.log 2>&1 &

# %%
import time

ready = False
for attempt in range(60):  # up to 10 minutes
    time.sleep(10)
    log = open("vllm.log").read() if __import__("os").path.exists("vllm.log") else ""
    if "Uvicorn running" in log or "Application startup complete" in log:
        ready = True
        break
    if "Traceback" in log and "ERROR" in log:
        print("vLLM logged an error while loading -- check the tail below.")
        break
    print(f"[{(attempt + 1) * 10}s] still loading...")

# !tail -n 60 vllm.log
print("\n--- server ready:", ready, "---\n")

# !curl -s http://localhost:8001/v1/chat/completions \
  -H "Content-Type: application/json" \
  -d '{"model":"raylab-nilechat-finetuned","messages":[{"role":"user","content":"hi"}],"max_tokens":16}'
# Out:
# [10s] still loading...
# [20s] still loading...
# [30s] still loading...
# [40s] still loading...
# [50s] still loading...
# [60s] still loading...
# [70s] still loading...
# [80s] still loading...
# [90s] still loading...
# [100s] still loading...
# [110s] still loading...
# [120s] still loading...
# [130s] still loading...
# [140s] still loading...
# [150s] still loading...
# [160s] still loading...
# [170s] still loading...
# [180s] still loading...
# [190s] still loading...
# [200s] still loading...
# [210s] still loading...
# [220s] still loading...
# [230s] still loading...
# [240s] still loading...
# [250s] still loading...
# [260s] still loading...
# [270s] still loading...
# [280s] still loading...
# [290s] still loading...
# [300s] still loading...
# [310s] still loading...
# Loading safetensors checkpoint shards: 100% Completed | 5/5 [00:06<00:00,  1.34s/it]
# (EngineCore pid=5436)
# (EngineCore pid=5436) INFO 08-27 20:12:52 [default_loader.py:430] Loading weights took 6.79 seconds
# (EngineCore pid=5436) INFO 08-27 20:12:53 [model_runner.py:380] Model loading took 22.62 GiB memory and 79.162686 seconds
# (EngineCore pid=5436) INFO 08-27 20:12:53 [topk_topp_sampler.py:62] Using FlashInfer for top-p & top-k sampling.
# (EngineCore pid=5436) INFO 08-27 20:13:12 [backends.py:1094] Using cache directory: /root/.cache/vllm/torch_compile_cache/f273e562d7/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore pid=5436) INFO 08-27 20:13:12 [backends.py:1155] Dynamo bytecode transform time: 15.99 s
# (EngineCore pid=5436) INFO 08-27 20:13:54 [backends.py:393] Compiling a graph for compile range (1, 2048) takes 41.82 s
# (EngineCore pid=5436) INFO 08-27 20:14:02 [backends.py:920] collected artifacts: 49 entries, 4 artifacts, 11721777 bytes total
# (EngineCore pid=5436) INFO 08-27 20:14:02 [decorators.py:708] saved AOT compiled function to /root/.cache/vllm/torch_compile_cache/torch_aot_compile/a1ca483098a84565eb34113d002c9545ce801b7a8b216c3dea553ee7e635550f/rank_0_0/model
# (EngineCore pid=5436) INFO 08-27 20:14:02 [monitor.py:53] torch.compile took 65.89 s in total
# (EngineCore pid=5436) INFO 08-27 20:14:02 [monitor.py:81] Initial profiling/warmup run took 0.33 s
# (EngineCore pid=5436) INFO 08-27 20:14:04 [gpu_worker.py:578] Available KV cache memory: 8.65 GiB
# (EngineCore pid=5436) INFO 08-27 20:14:05 [kv_cache_utils.py:1869] GPU KV cache size: 34,261 tokens, Maximum concurrency for 8,192 tokens per request: 4.18x
# Capturing CUDA graphs (PIECEWISE): 100%|██████████| 51/51 [00:05<00:00,  9.10it/s]
# Capturing CUDA graphs (FULL): 100%|██████████| 35/35 [00:02<00:00, 16.09it/s]
# (EngineCore pid=5436) INFO 08-27 20:14:14 [model_runner.py:906] Graph capturing finished in 8 secs, took 0.73 GiB
# (EngineCore pid=5436) INFO 08-27 20:14:14 [gpu_worker.py:804] Free memory on device (39.08/39.49 GiB) on startup. Desired GPU memory utilization is (0.85, 33.57 GiB). Actual usage is 23.02 GiB for consumed memory (weights + non-torch), 1.9 GiB for peak activation, and 0.73 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=8343313716` (7.77 GiB) to fit into requested memory, or `--kv-cache-memory=14255467008` (13.28 GiB) to fully utilize gpu memory. Current kv cache memory in use is 8.65 GiB.
# (EngineCore pid=5436) INFO 08-27 20:15:59 [jit_monitor.py:85] Kernel JIT monitor activated; monitored JIT compilations during inference will use mode=warn.
# (EngineCore pid=5436) INFO 08-27 20:15:59 [torch_utils.py:262] Reducing Torch threads from 6 to 1 for serving. Set OMP_NUM_THREADS in the external environment to override.
# (EngineCore pid=5436) INFO 08-27 20:15:59 [core.py:347] init engine (profile, create kv cache, warmup model) took 186.86 s (compilation: 65.89 s)
# (EngineCore pid=5436) INFO 08-27 20:16:03 [kernel.py:308] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# (APIServer pid=5208) INFO 08-27 20:16:03 [api_server.py:653] Supported tasks: ['generate']
# (APIServer pid=5208) INFO 08-27 20:16:05 [hf.py:551] Detected the chat template content format to be 'openai'. You can set `--chat-template-content-format` to override this.
# (APIServer pid=5208) WARNING 08-27 20:16:05 [model.py:1713] Default vLLM sampling parameters have been overridden by the model's `generation_config.json`: `{'repetition_penalty': 1.1, 'top_k': 64, 'top_p': 0.95}`. If this is not intended, please relaunch vLLM instance with `--generation-config vllm`.
# (APIServer pid=5208) INFO 08-27 20:16:05 [api_server.py:657] Starting vLLM server on http://0.0.0.0:8001
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:51] Available routes are:
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /openapi.json, Methods: GET, HEAD
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /docs, Methods: GET, HEAD
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /docs/oauth2-redirect, Methods: GET, HEAD
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /redoc, Methods: GET, HEAD
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /load, Methods: GET
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /version, Methods: GET
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /health, Methods: GET
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /metrics, Methods: GET
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /tokenize, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /detokenize, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/models, Methods: GET
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /ping, Methods: GET
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /ping, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /invocations, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/chat/completions, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/chat/completions/batch, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/responses, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/responses/{response_id}, Methods: GET
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/responses/{response_id}/cancel, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/completions, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/messages, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/messages/count_tokens, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /generative_scoring, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /scale_elastic_ep, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /is_scaling_elastic_ep, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/chat/completions/render, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/completions/render, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/chat/completions/derender, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /v1/completions/derender, Methods: POST
# (APIServer pid=5208) INFO 08-27 20:16:05 [launcher.py:60] Route: /inference/v1/generate, Methods: POST
# (APIServer pid=5208) INFO:     Started server process [5208]
# (APIServer pid=5208) INFO:     Waiting for application startup.
# (APIServer pid=5208) INFO:     Application startup complete.
#
# --- server ready: True ---
#
# {"id":"chatcmpl-99a08775c1d2c206","object":"chat.completion","created":1787861773,"model":"raylab-nilechat-finetuned","choices":[{"index":0,"message":{"role":"assistant","content":"```json\n{}\n```\n\nوعليكم السلام يا فندم،","refusal":null,"annotations":null,"audio":null,"function_call":null,"reasoning":null},"logprobs":null,"finish_reason":"length","stop_reason":null,"token_ids":null,"routed_experts":null}],"service_tier":null,"system_fingerprint":"vllm-0.28.0-ffd20a0f","usage":{"prompt_tokens":10,"total_tokens":26,"completion_tokens":16,"prompt_tokens_details":null,"completion_tokens_details":null},"prompt_logprobs":null,"prompt_token_ids":null,"prompt_text":null,"kv_transfer_params":null,"ec_transfer_params":null,"metrics":null}

# %% [markdown]
# If the curl call above didn't return a real completion, stop and fix it before opening a tunnel.

# %%
import os, re, time

if not os.path.exists("cloudflared-linux-amd64"):
    # !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64

assert os.path.exists("cloudflared-linux-amd64") and os.path.getsize("cloudflared-linux-amd64") > 0, \
    "cloudflared download failed -- re-run this cell, or check Colab's network connectivity"

# !chmod +x cloudflared-linux-amd64
# !nohup ./cloudflared-linux-amd64 tunnel --url http://localhost:8001 > cloudflared.log 2>&1 &

tunnel_url = None
for _ in range(30):
    time.sleep(2)
    log = open("cloudflared.log").read() if os.path.exists("cloudflared.log") else ""
    match = re.search(r"https://[a-zA-Z0-9-]+\.trycloudflare\.com", log)
    if match:
        tunnel_url = match.group(0)
        break

assert tunnel_url, "Tunnel URL not found after 60s -- check cloudflared.log for errors and re-run this cell"
print(f"Tunnel URL: {tunnel_url}")
print("Set in your local src/.env:")
print(f"  GENERATION_BASE_URL={tunnel_url}")
print("  GENERATION_MODEL_NAME=raylab-nilechat-finetuned")
# Out:
# Tunnel URL: https://helped-angela-drove-mercy.trycloudflare.com
# Set in your local src/.env:
#   GENERATION_BASE_URL=https://helped-angela-drove-mercy.trycloudflare.com
#   GENERATION_MODEL_NAME=raylab-nilechat-finetuned

# %%
# !curl -s http://localhost:8001/v1/chat/completions \
  -H "Content-Type: application/json" \
  -d '{"model":"raylab-nilechat-finetuned","messages":[{"role":"user","content":"إزيك؟"}],"max_tokens":32}'
# Out:
# {"id":"chatcmpl-b66365b6c0bf18b0","object":"chat.completion","created":1787862041,"model":"raylab-nilechat-finetuned","choices":[{"index":0,"message":{"role":"assistant","content":"```json\n{}\n```\n\nوعليكم السلام ورحمة الله، أنا هنا عشان أساعدك في أي حاجة تحب تسألها! ق","refusal":null,"annotations":null,"audio":null,"function_call":null,"reasoning":null},"logprobs":null,"finish_reason":"length","stop_reason":null,"token_ids":null,"routed_experts":null}],"service_tier":null,"system_fingerprint":"vllm-0.28.0-ffd20a0f","usage":{"prompt_tokens":13,"total_tokens":45,"completion_tokens":32,"prompt_tokens_details":null,"completion_tokens_details":null},"prompt_logprobs":null,"prompt_token_ids":null,"prompt_text":null,"kv_transfer_params":null,"ec_transfer_params":null,"metrics":null}
